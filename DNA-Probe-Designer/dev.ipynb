# %%
from duplex_prob import filter_duplex_prob

sam_file = '../data/test_outputs/rosa26.sam'
bed_file = '../data/test_outputs/rosa26_probes.bed'

filter_duplex_prob(sam_file, bed_file, 42, 0.2)

# %%
from duplex_prob import plot_duplex_prob

filtered_file = '_pDup_filtered.bed'

plot_duplex_prob(filtered_file, probe_num='all')

# %%
from secondary_structure import filter_secondary_structure
from duplex_prob import plot_duplex_prob

filter_secondary_structure('_pDup_filtered.bed', 0)
plot_duplex_prob('_pDup_MFE_filtered.bed')
